# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

#print check
print(weather_api_key)

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy
# Out:
# 25cbe733b5818eb3fec3338d511bcbf5

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 644

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&appid={weather_api_key}&units={units}"

    #print check
    print(city_url)

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # pprint(city_weather)

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# https://api.openweathermap.org/data/2.5/weather?q=atuona&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 1 of Set 1 | atuona
# https://api.openweathermap.org/data/2.5/weather?q=paciran&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 2 of Set 1 | paciran
# https://api.openweathermap.org/data/2.5/weather?q=mahibadhoo&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 3 of Set 1 | mahibadhoo
# https://api.openweathermap.org/data/2.5/weather?q=alotau&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 4 of Set 1 | alotau
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=sao joao da barra&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 5 of Set 1 | sao joao da barra
# https://api.openweathermap.org/data/2.5/weather?q=belushya guba&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 6 of Set 1 | belushya guba
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=talnakh&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 7 of Set 1 | talnakh
# https://api.openweathermap.org/data/2.5/weather?q=port elizabeth&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 8 of Set 1 | port elizabeth
# https://api.openweathermap.org/data/2.5/weather?q=busselton&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 9 of Set 1 | busselton
# https://api.openweathermap.org/data/2.5/weather?q=half moon bay&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 10 of Set 1 | half moon bay
# https://api.openweathermap.org/data/2.5/weather?q=victoria&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 11 of Set 1 | victoria
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=tiksi&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 12 of Set 1 | tiksi
# https://api.openweathermap.org/data/2.5/weather?q=werda&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 13 of Set 1 | werda
# https://api.openweathermap.org/data/2.5/weather?q=sao paulo de olivenca&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 14 of Set 1 | sao paulo de olivenca
# https://api.openweathermap.org/data/2.5/weather?q=illoqqortoormiut&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 15 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=avarua&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 16 of Set 1 | avarua
# https://api.openweathermap.org/data/2.5/weather?q=amderma&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 17 of Set 1 | amderma
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=abha&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 18 of Set 1 | abha
# https://api.openweathermap.org/data/2.5/weather?q=torbay&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 19 of Set 1 | torbay
# https://api.openweathermap.org/data/2.5/weather?q=hithadhoo&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 20 of Set 1 | hithadhoo
# https://api.openweathermap.org/data/2.5/weather?q=port alfred&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 21 of Set 1 | port alfred
# https://api.openweathermap.org/data/2.5/weather?q=barybino&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 22 of Set 1 | barybino
# https://api.openweathermap.org/data/2.5/weather?q=oxford&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 23 of Set 1 | oxford
# https://api.openweathermap.org/data/2.5/weather?q=xifeng&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 24 of Set 1 | xifeng
# https://api.openweathermap.org/data/2.5/weather?q=albany&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 25 of Set 1 | albany
# https://api.openweathermap.org/data/2.5/weather?q=mahebourg&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 26 of Set 1 | mahebourg
# https://api.openweathermap.org/data/2.5/weather?q=punta arenas&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 27 of Set 1 | punta arenas
# https://api.openweathermap.org/data/2.5/weather?q=rikitea&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 28 of Set 1 | rikitea
# https://api.openweathermap.org/data/2.5/weather?q=alingsas&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 29 of Set 1 | alingsas
# https://api.openweathermap.org/data/2.5/weather?q=vaini&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 30 of Set 1 | vaini
# https://api.openweathermap.org/data/2.5/weather?q=hilo&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 31 of Set 1 | hilo
# https://api.openweathermap.org/data/2.5/weather?q=shaoguan&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 32 of Set 1 | shaoguan
# https://api.openweathermap.org/data/2.5/weather?q=carnarvon&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 33 of Set 1 | carnarvon
# https://api.openweathermap.org/data/2.5/weather?q=sola&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 34 of Set 1 | sola
# https://api.openweathermap.org/data/2.5/weather?q=puri&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 35 of Set 1 | puri
# https://api.openweathermap.org/data/2.5/weather?q=nenjiang&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 36 of Set 1 | nenjiang
# https://api.openweathermap.org/data/2.5/weather?q=sitka&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 37 of Set 1 | sitka
# https://api.openweathermap.org/data/2.5/weather?q=tuktoyaktuk&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 38 of Set 1 | tuktoyaktuk
# https://api.openweathermap.org/data/2.5/weather?q=rocha&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 39 of Set 1 | rocha
# https://api.openweathermap.org/data/2.5/weather?q=kapaa&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 40 of Set 1 | kapaa
# https://api.openweathermap.org/data/2.5/weather?q=ribeira grande&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 41 of Set 1 | ribeira grande
# https://api.openweathermap.org/data/2.5/weather?q=yellowknife&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 42 of Set 1 | yellowknife
# https://api.openweathermap.org/data/2.5/weather?q=cape town&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 43 of Set 1 | cape town
# https://api.openweathermap.org/data/2.5/weather?q=hermanus&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 44 of Set 1 | hermanus
# https://api.openweathermap.org/data/2.5/weather?q=qaanaaq&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 45 of Set 1 | qaanaaq
# https://api.openweathermap.org/data/2.5/weather?q=waipawa&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 46 of Set 1 | waipawa
# https://api.openweathermap.org/data/2.5/weather?q=camopi&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 47 of Set 1 | camopi
# https://api.openweathermap.org/data/2.5/weather?q=bluff&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 48 of Set 1 | bluff
# https://api.openweathermap.org/data/2.5/weather?q=villa maria&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 49 of Set 1 | villa maria
# https://api.openweathermap.org/data/2.5/weather?q=mataura&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 50 of Set 1 | mataura
# https://api.openweathermap.org/data/2.5/weather?q=lebu&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 0 of Set 2 | lebu
# https://api.openweathermap.org/data/2.5/weather?q=yulara&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 1 of Set 2 | yulara
# https://api.openweathermap.org/data/2.5/weather?q=nabul&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 2 of Set 2 | nabul
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=port macquarie&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 3 of Set 2 | port macquarie
# https://api.openweathermap.org/data/2.5/weather?q=maputo&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 4 of Set 2 | maputo
# https://api.openweathermap.org/data/2.5/weather?q=mugur-aksy&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 5 of Set 2 | mugur-aksy
# https://api.openweathermap.org/data/2.5/weather?q=aykhal&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 6 of Set 2 | aykhal
# https://api.openweathermap.org/data/2.5/weather?q=aksarka&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 7 of Set 2 | aksarka
# https://api.openweathermap.org/data/2.5/weather?q=lolua&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 8 of Set 2 | lolua
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=saint-augustin&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 9 of Set 2 | saint-augustin
# https://api.openweathermap.org/data/2.5/weather?q=arraial do cabo&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 10 of Set 2 | arraial do cabo
# https://api.openweathermap.org/data/2.5/weather?q=tromso&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 11 of Set 2 | tromso
# https://api.openweathermap.org/data/2.5/weather?q=rungata&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 12 of Set 2 | rungata
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=mpanda&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 13 of Set 2 | mpanda
# https://api.openweathermap.org/data/2.5/weather?q=conceicao da barra&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 14 of Set 2 | conceicao da barra
# https://api.openweathermap.org/data/2.5/weather?q=gwembe&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 15 of Set 2 | gwembe
# https://api.openweathermap.org/data/2.5/weather?q=huntington&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 16 of Set 2 | huntington
# https://api.openweathermap.org/data/2.5/weather?q=fayetteville&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 17 of Set 2 | fayetteville
# https://api.openweathermap.org/data/2.5/weather?q=hobart&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 18 of Set 2 | hobart
# https://api.openweathermap.org/data/2.5/weather?q=georgetown&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 19 of Set 2 | georgetown
# https://api.openweathermap.org/data/2.5/weather?q=kasongo-lunda&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 20 of Set 2 | kasongo-lunda
# https://api.openweathermap.org/data/2.5/weather?q=neyshabur&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 21 of Set 2 | neyshabur
# https://api.openweathermap.org/data/2.5/weather?q=grindavik&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 22 of Set 2 | grindavik
# https://api.openweathermap.org/data/2.5/weather?q=flin flon&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 23 of Set 2 | flin flon
# https://api.openweathermap.org/data/2.5/weather?q=lac du bonnet&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 24 of Set 2 | lac du bonnet
# https://api.openweathermap.org/data/2.5/weather?q=okhotsk&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 25 of Set 2 | okhotsk
# https://api.openweathermap.org/data/2.5/weather?q=kamaishi&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 26 of Set 2 | kamaishi
# https://api.openweathermap.org/data/2.5/weather?q=aklavik&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 27 of Set 2 | aklavik
# https://api.openweathermap.org/data/2.5/weather?q=barcelona&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 28 of Set 2 | barcelona
# https://api.openweathermap.org/data/2.5/weather?q=grand centre&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 29 of Set 2 | grand centre
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=barrow&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 30 of Set 2 | barrow
# https://api.openweathermap.org/data/2.5/weather?q=ushuaia&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 31 of Set 2 | ushuaia
# https://api.openweathermap.org/data/2.5/weather?q=narsaq&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 32 of Set 2 | narsaq
# https://api.openweathermap.org/data/2.5/weather?q=gat&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 33 of Set 2 | gat
# https://api.openweathermap.org/data/2.5/weather?q=toumodi&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 34 of Set 2 | toumodi
# https://api.openweathermap.org/data/2.5/weather?q=mys shmidta&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 35 of Set 2 | mys shmidta
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=upernavik&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 36 of Set 2 | upernavik
# https://api.openweathermap.org/data/2.5/weather?q=yar-sale&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 37 of Set 2 | yar-sale
# https://api.openweathermap.org/data/2.5/weather?q=oudtshoorn&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 38 of Set 2 | oudtshoorn
# https://api.openweathermap.org/data/2.5/weather?q=evensk&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 39 of Set 2 | evensk
# https://api.openweathermap.org/data/2.5/weather?q=hay river&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 40 of Set 2 | hay river
# https://api.openweathermap.org/data/2.5/weather?q=port lincoln&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 41 of Set 2 | port lincoln
# https://api.openweathermap.org/data/2.5/weather?q=chuy&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 42 of Set 2 | chuy
# https://api.openweathermap.org/data/2.5/weather?q=norman wells&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 43 of Set 2 | norman wells
# https://api.openweathermap.org/data/2.5/weather?q=neyyattinkara&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 44 of Set 2 | neyyattinkara
# https://api.openweathermap.org/data/2.5/weather?q=nova odesa&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 45 of Set 2 | nova odesa
# https://api.openweathermap.org/data/2.5/weather?q=artyk&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 46 of Set 2 | artyk
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=charters towers&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 47 of Set 2 | charters towers
# https://api.openweathermap.org/data/2.5/weather?q=east london&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 48 of Set 2 | east london
# https://api.openweathermap.org/data/2.5/weather?q=zhigansk&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 49 of Set 2 | zhigansk
# https://api.openweathermap.org/data/2.5/weather?q=airai&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 0 of Set 3 | airai
# https://api.openweathermap.org/data/2.5/weather?q=geelong&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 1 of Set 3 | geelong
# https://api.openweathermap.org/data/2.5/weather?q=nizhneyansk&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 2 of Set 3 | nizhneyansk
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=atambua&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 3 of Set 3 | atambua
# https://api.openweathermap.org/data/2.5/weather?q=kruisfontein&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 4 of Set 3 | kruisfontein
# https://api.openweathermap.org/data/2.5/weather?q=thompson&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 5 of Set 3 | thompson
# https://api.openweathermap.org/data/2.5/weather?q=port hawkesbury&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 6 of Set 3 | port hawkesbury
# https://api.openweathermap.org/data/2.5/weather?q=santa cruz de tenerife&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 7 of Set 3 | santa cruz de tenerife
# https://api.openweathermap.org/data/2.5/weather?q=joshimath&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 8 of Set 3 | joshimath
# https://api.openweathermap.org/data/2.5/weather?q=paamiut&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 9 of Set 3 | paamiut
# https://api.openweathermap.org/data/2.5/weather?q=bathsheba&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 10 of Set 3 | bathsheba
# https://api.openweathermap.org/data/2.5/weather?q=togur&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 11 of Set 3 | togur
# https://api.openweathermap.org/data/2.5/weather?q=grand river south east&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 12 of Set 3 | grand river south east
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=iqaluit&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 13 of Set 3 | iqaluit
# https://api.openweathermap.org/data/2.5/weather?q=honiara&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 14 of Set 3 | honiara
# https://api.openweathermap.org/data/2.5/weather?q=butaritari&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 15 of Set 3 | butaritari
# https://api.openweathermap.org/data/2.5/weather?q=puerto ayora&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 16 of Set 3 | puerto ayora
# https://api.openweathermap.org/data/2.5/weather?q=ekibastuz&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 17 of Set 3 | ekibastuz
# https://api.openweathermap.org/data/2.5/weather?q=cabo san lucas&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 18 of Set 3 | cabo san lucas
# https://api.openweathermap.org/data/2.5/weather?q=souillac&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 19 of Set 3 | souillac
# https://api.openweathermap.org/data/2.5/weather?q=tres coracoes&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 20 of Set 3 | tres coracoes
# https://api.openweathermap.org/data/2.5/weather?q=khatanga&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 21 of Set 3 | khatanga
# https://api.openweathermap.org/data/2.5/weather?q=formoso do araguaia&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 22 of Set 3 | formoso do araguaia
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=peterhead&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 23 of Set 3 | peterhead
# https://api.openweathermap.org/data/2.5/weather?q=hudiksvall&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 24 of Set 3 | hudiksvall
# https://api.openweathermap.org/data/2.5/weather?q=domat&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 25 of Set 3 | domat
# https://api.openweathermap.org/data/2.5/weather?q=hambantota&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 26 of Set 3 | hambantota
# https://api.openweathermap.org/data/2.5/weather?q=ukiah&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 27 of Set 3 | ukiah
# https://api.openweathermap.org/data/2.5/weather?q=anupgarh&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 28 of Set 3 | anupgarh
# https://api.openweathermap.org/data/2.5/weather?q=severo-kurilsk&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 29 of Set 3 | severo-kurilsk
# https://api.openweathermap.org/data/2.5/weather?q=chokurdakh&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 30 of Set 3 | chokurdakh
# https://api.openweathermap.org/data/2.5/weather?q=kijang&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 31 of Set 3 | kijang
# https://api.openweathermap.org/data/2.5/weather?q=attawapiskat&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 32 of Set 3 | attawapiskat
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=saint george&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 33 of Set 3 | saint george
# https://api.openweathermap.org/data/2.5/weather?q=saskylakh&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 34 of Set 3 | saskylakh
# https://api.openweathermap.org/data/2.5/weather?q=sentyabrskiy&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 35 of Set 3 | sentyabrskiy
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=dunedin&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 36 of Set 3 | dunedin
# https://api.openweathermap.org/data/2.5/weather?q=sao filipe&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 37 of Set 3 | sao filipe
# https://api.openweathermap.org/data/2.5/weather?q=chagda&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 38 of Set 3 | chagda
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=penzance&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 39 of Set 3 | penzance
# https://api.openweathermap.org/data/2.5/weather?q=northam&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 40 of Set 3 | northam
# https://api.openweathermap.org/data/2.5/weather?q=strezhevoy&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 41 of Set 3 | strezhevoy
# https://api.openweathermap.org/data/2.5/weather?q=mandera&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 42 of Set 3 | mandera
# https://api.openweathermap.org/data/2.5/weather?q=barentsburg&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 43 of Set 3 | barentsburg
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=umzimvubu&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 44 of Set 3 | umzimvubu
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=jamestown&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 45 of Set 3 | jamestown
# https://api.openweathermap.org/data/2.5/weather?q=arlit&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 46 of Set 3 | arlit
# https://api.openweathermap.org/data/2.5/weather?q=eston&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 47 of Set 3 | eston
# https://api.openweathermap.org/data/2.5/weather?q=mogadishu&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 48 of Set 3 | mogadishu
# https://api.openweathermap.org/data/2.5/weather?q=pevek&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 49 of Set 3 | pevek
# https://api.openweathermap.org/data/2.5/weather?q=kodiak&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 0 of Set 4 | kodiak
# https://api.openweathermap.org/data/2.5/weather?q=gorur&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 1 of Set 4 | gorur
# https://api.openweathermap.org/data/2.5/weather?q=riacho de santana&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 2 of Set 4 | riacho de santana
# https://api.openweathermap.org/data/2.5/weather?q=lichuan&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 3 of Set 4 | lichuan
# https://api.openweathermap.org/data/2.5/weather?q=new norfolk&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 4 of Set 4 | new norfolk
# https://api.openweathermap.org/data/2.5/weather?q=alofi&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 5 of Set 4 | alofi
# https://api.openweathermap.org/data/2.5/weather?q=tautira&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 6 of Set 4 | tautira
# https://api.openweathermap.org/data/2.5/weather?q=uruzgan&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 7 of Set 4 | uruzgan
# https://api.openweathermap.org/data/2.5/weather?q=namibe&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 8 of Set 4 | namibe
# https://api.openweathermap.org/data/2.5/weather?q=taolanaro&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 9 of Set 4 | taolanaro
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=cidreira&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 10 of Set 4 | cidreira
# https://api.openweathermap.org/data/2.5/weather?q=belyy yar&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 11 of Set 4 | belyy yar
# https://api.openweathermap.org/data/2.5/weather?q=sinnamary&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 12 of Set 4 | sinnamary
# https://api.openweathermap.org/data/2.5/weather?q=beloha&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 13 of Set 4 | beloha
# https://api.openweathermap.org/data/2.5/weather?q=mayor pablo lagerenza&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 14 of Set 4 | mayor pablo lagerenza
# https://api.openweathermap.org/data/2.5/weather?q=hofn&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 15 of Set 4 | hofn
# https://api.openweathermap.org/data/2.5/weather?q=teahupoo&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 16 of Set 4 | teahupoo
# https://api.openweathermap.org/data/2.5/weather?q=vila franca do campo&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 17 of Set 4 | vila franca do campo
# https://api.openweathermap.org/data/2.5/weather?q=kosh-agach&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 18 of Set 4 | kosh-agach
# https://api.openweathermap.org/data/2.5/weather?q=ocampo&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 19 of Set 4 | ocampo
# https://api.openweathermap.org/data/2.5/weather?q=atikokan&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 20 of Set 4 | atikokan
# https://api.openweathermap.org/data/2.5/weather?q=jiddah&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 21 of Set 4 | jiddah
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=yatou&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 22 of Set 4 | yatou
# https://api.openweathermap.org/data/2.5/weather?q=san joaquin&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 23 of Set 4 | san joaquin
# https://api.openweathermap.org/data/2.5/weather?q=alta floresta&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 24 of Set 4 | alta floresta
# https://api.openweathermap.org/data/2.5/weather?q=mrirt&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 25 of Set 4 | mrirt
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=jining&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 26 of Set 4 | jining
# https://api.openweathermap.org/data/2.5/weather?q=smithers&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 27 of Set 4 | smithers
# https://api.openweathermap.org/data/2.5/weather?q=turayf&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 28 of Set 4 | turayf
# https://api.openweathermap.org/data/2.5/weather?q=khuzdar&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 29 of Set 4 | khuzdar
# https://api.openweathermap.org/data/2.5/weather?q=tsaratanana&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 30 of Set 4 | tsaratanana
# https://api.openweathermap.org/data/2.5/weather?q=japura&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 31 of Set 4 | japura
# https://api.openweathermap.org/data/2.5/weather?q=rawson&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 32 of Set 4 | rawson
# https://api.openweathermap.org/data/2.5/weather?q=mount gambier&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 33 of Set 4 | mount gambier
# https://api.openweathermap.org/data/2.5/weather?q=henties bay&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 34 of Set 4 | henties bay
# https://api.openweathermap.org/data/2.5/weather?q=inhambane&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 35 of Set 4 | inhambane
# https://api.openweathermap.org/data/2.5/weather?q=ancud&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 36 of Set 4 | ancud
# https://api.openweathermap.org/data/2.5/weather?q=tumannyy&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 37 of Set 4 | tumannyy
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=sao joao do piaui&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 38 of Set 4 | sao joao do piaui
# https://api.openweathermap.org/data/2.5/weather?q=cherskiy&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 39 of Set 4 | cherskiy
# https://api.openweathermap.org/data/2.5/weather?q=poltavka&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 40 of Set 4 | poltavka
# https://api.openweathermap.org/data/2.5/weather?q=dikson&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 41 of Set 4 | dikson
# https://api.openweathermap.org/data/2.5/weather?q=bengkulu&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 42 of Set 4 | bengkulu
# https://api.openweathermap.org/data/2.5/weather?q=ystad&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 43 of Set 4 | ystad
# https://api.openweathermap.org/data/2.5/weather?q=tsihombe&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 44 of Set 4 | tsihombe
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=geraldton&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 45 of Set 4 | geraldton
# https://api.openweathermap.org/data/2.5/weather?q=lima&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 46 of Set 4 | lima
# https://api.openweathermap.org/data/2.5/weather?q=daru&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 47 of Set 4 | daru
# https://api.openweathermap.org/data/2.5/weather?q=selikhino&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 48 of Set 4 | selikhino
# https://api.openweathermap.org/data/2.5/weather?q=bedele&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 49 of Set 4 | bedele
# https://api.openweathermap.org/data/2.5/weather?q=monrovia&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 0 of Set 5 | monrovia
# https://api.openweathermap.org/data/2.5/weather?q=angola&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 1 of Set 5 | angola
# https://api.openweathermap.org/data/2.5/weather?q=lasa&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 2 of Set 5 | lasa
# https://api.openweathermap.org/data/2.5/weather?q=requena&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 3 of Set 5 | requena
# https://api.openweathermap.org/data/2.5/weather?q=pangkalanbuun&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 4 of Set 5 | pangkalanbuun
# https://api.openweathermap.org/data/2.5/weather?q=nakamura&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 5 of Set 5 | nakamura
# https://api.openweathermap.org/data/2.5/weather?q=fare&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 6 of Set 5 | fare
# https://api.openweathermap.org/data/2.5/weather?q=saint-francois&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 7 of Set 5 | saint-francois
# https://api.openweathermap.org/data/2.5/weather?q=ponta do sol&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 8 of Set 5 | ponta do sol
# https://api.openweathermap.org/data/2.5/weather?q=codrington&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 9 of Set 5 | codrington
# https://api.openweathermap.org/data/2.5/weather?q=hammerfest&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 10 of Set 5 | hammerfest
# https://api.openweathermap.org/data/2.5/weather?q=tshikapa&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 11 of Set 5 | tshikapa
# https://api.openweathermap.org/data/2.5/weather?q=namwala&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 12 of Set 5 | namwala
# https://api.openweathermap.org/data/2.5/weather?q=padang&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 13 of Set 5 | padang
# https://api.openweathermap.org/data/2.5/weather?q=mar del plata&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 14 of Set 5 | mar del plata
# https://api.openweathermap.org/data/2.5/weather?q=loding&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 15 of Set 5 | loding
# https://api.openweathermap.org/data/2.5/weather?q=sabha&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 16 of Set 5 | sabha
# https://api.openweathermap.org/data/2.5/weather?q=solnechnyy&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 17 of Set 5 | solnechnyy
# https://api.openweathermap.org/data/2.5/weather?q=nanortalik&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 18 of Set 5 | nanortalik
# https://api.openweathermap.org/data/2.5/weather?q=kaeo&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 19 of Set 5 | kaeo
# https://api.openweathermap.org/data/2.5/weather?q=castro&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 20 of Set 5 | castro
# https://api.openweathermap.org/data/2.5/weather?q=vaitupu&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 21 of Set 5 | vaitupu
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=saint-philippe&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 22 of Set 5 | saint-philippe
# https://api.openweathermap.org/data/2.5/weather?q=komsomolskiy&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 23 of Set 5 | komsomolskiy
# https://api.openweathermap.org/data/2.5/weather?q=constitucion&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 24 of Set 5 | constitucion
# https://api.openweathermap.org/data/2.5/weather?q=amapa&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 25 of Set 5 | amapa
# https://api.openweathermap.org/data/2.5/weather?q=stornoway&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 26 of Set 5 | stornoway
# https://api.openweathermap.org/data/2.5/weather?q=kibala&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 27 of Set 5 | kibala
# https://api.openweathermap.org/data/2.5/weather?q=sechura&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 28 of Set 5 | sechura
# https://api.openweathermap.org/data/2.5/weather?q=trinidad&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 29 of Set 5 | trinidad
# https://api.openweathermap.org/data/2.5/weather?q=sobolevo&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 30 of Set 5 | sobolevo
# https://api.openweathermap.org/data/2.5/weather?q=bure&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 31 of Set 5 | bure
# https://api.openweathermap.org/data/2.5/weather?q=bilma&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 32 of Set 5 | bilma
# https://api.openweathermap.org/data/2.5/weather?q=kulevcha&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 33 of Set 5 | kulevcha
# https://api.openweathermap.org/data/2.5/weather?q=bredasdorp&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 34 of Set 5 | bredasdorp
# https://api.openweathermap.org/data/2.5/weather?q=makakilo city&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 35 of Set 5 | makakilo city
# https://api.openweathermap.org/data/2.5/weather?q=laguna&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 36 of Set 5 | laguna
# https://api.openweathermap.org/data/2.5/weather?q=broome&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 37 of Set 5 | broome
# https://api.openweathermap.org/data/2.5/weather?q=pisco&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 38 of Set 5 | pisco
# https://api.openweathermap.org/data/2.5/weather?q=kholm&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 39 of Set 5 | kholm
# https://api.openweathermap.org/data/2.5/weather?q=korla&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 40 of Set 5 | korla
# https://api.openweathermap.org/data/2.5/weather?q=xinglongshan&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 41 of Set 5 | xinglongshan
# https://api.openweathermap.org/data/2.5/weather?q=timberlake&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 42 of Set 5 | timberlake
# https://api.openweathermap.org/data/2.5/weather?q=listvyagi&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 43 of Set 5 | listvyagi
# https://api.openweathermap.org/data/2.5/weather?q=tuatapere&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 44 of Set 5 | tuatapere
# https://api.openweathermap.org/data/2.5/weather?q=itanhandu&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 45 of Set 5 | itanhandu
# https://api.openweathermap.org/data/2.5/weather?q=dong hoi&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 46 of Set 5 | dong hoi
# https://api.openweathermap.org/data/2.5/weather?q=manggar&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 47 of Set 5 | manggar
# https://api.openweathermap.org/data/2.5/weather?q=phalaborwa&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 48 of Set 5 | phalaborwa
# https://api.openweathermap.org/data/2.5/weather?q=pafos&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 49 of Set 5 | pafos
# https://api.openweathermap.org/data/2.5/weather?q=ust-kamchatsk&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 0 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=tingi&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 1 of Set 6 | tingi
# https://api.openweathermap.org/data/2.5/weather?q=poso&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 2 of Set 6 | poso
# https://api.openweathermap.org/data/2.5/weather?q=puerto cabezas&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 3 of Set 6 | puerto cabezas
# https://api.openweathermap.org/data/2.5/weather?q=beringovskiy&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 4 of Set 6 | beringovskiy
# https://api.openweathermap.org/data/2.5/weather?q=vardo&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 5 of Set 6 | vardo
# https://api.openweathermap.org/data/2.5/weather?q=lompoc&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 6 of Set 6 | lompoc
# https://api.openweathermap.org/data/2.5/weather?q=gamba&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 7 of Set 6 | gamba
# https://api.openweathermap.org/data/2.5/weather?q=nacozari&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 8 of Set 6 | nacozari
# https://api.openweathermap.org/data/2.5/weather?q=mahina&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 9 of Set 6 | mahina
# https://api.openweathermap.org/data/2.5/weather?q=lavrentiya&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 10 of Set 6 | lavrentiya
# https://api.openweathermap.org/data/2.5/weather?q=batemans bay&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 11 of Set 6 | batemans bay
# https://api.openweathermap.org/data/2.5/weather?q=kirkuk&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 12 of Set 6 | kirkuk
# https://api.openweathermap.org/data/2.5/weather?q=ponta delgada&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 13 of Set 6 | ponta delgada
# https://api.openweathermap.org/data/2.5/weather?q=mehamn&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 14 of Set 6 | mehamn
# https://api.openweathermap.org/data/2.5/weather?q=marsa matruh&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 15 of Set 6 | marsa matruh
# https://api.openweathermap.org/data/2.5/weather?q=provideniya&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 16 of Set 6 | provideniya
# https://api.openweathermap.org/data/2.5/weather?q=panaba&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 17 of Set 6 | panaba
# https://api.openweathermap.org/data/2.5/weather?q=esil&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 18 of Set 6 | esil
# https://api.openweathermap.org/data/2.5/weather?q=valdivia&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 19 of Set 6 | valdivia
# https://api.openweathermap.org/data/2.5/weather?q=hai duong&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 20 of Set 6 | hai duong
# https://api.openweathermap.org/data/2.5/weather?q=viligili&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 21 of Set 6 | viligili
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=ust-omchug&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 22 of Set 6 | ust-omchug
# https://api.openweathermap.org/data/2.5/weather?q=pangody&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 23 of Set 6 | pangody
# https://api.openweathermap.org/data/2.5/weather?q=makokou&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 24 of Set 6 | makokou
# https://api.openweathermap.org/data/2.5/weather?q=bongandanga&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 25 of Set 6 | bongandanga
# https://api.openweathermap.org/data/2.5/weather?q=tasiilaq&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 26 of Set 6 | tasiilaq
# https://api.openweathermap.org/data/2.5/weather?q=quarai&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 27 of Set 6 | quarai
# https://api.openweathermap.org/data/2.5/weather?q=bethel&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 28 of Set 6 | bethel
# https://api.openweathermap.org/data/2.5/weather?q=hokitika&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 29 of Set 6 | hokitika
# https://api.openweathermap.org/data/2.5/weather?q=sioux lookout&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 30 of Set 6 | sioux lookout
# https://api.openweathermap.org/data/2.5/weather?q=sibu&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 31 of Set 6 | sibu
# https://api.openweathermap.org/data/2.5/weather?q=karatau&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 32 of Set 6 | karatau
# https://api.openweathermap.org/data/2.5/weather?q=marv dasht&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 33 of Set 6 | marv dasht
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=coquimbo&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 34 of Set 6 | coquimbo
# https://api.openweathermap.org/data/2.5/weather?q=ballina&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 35 of Set 6 | ballina
# https://api.openweathermap.org/data/2.5/weather?q=pangnirtung&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 36 of Set 6 | pangnirtung
# https://api.openweathermap.org/data/2.5/weather?q=grand-lahou&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 37 of Set 6 | grand-lahou
# https://api.openweathermap.org/data/2.5/weather?q=wajid&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 38 of Set 6 | wajid
# https://api.openweathermap.org/data/2.5/weather?q=nikolskoye&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 39 of Set 6 | nikolskoye
# https://api.openweathermap.org/data/2.5/weather?q=volokolamsk&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 40 of Set 6 | volokolamsk
# https://api.openweathermap.org/data/2.5/weather?q=byron bay&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 41 of Set 6 | byron bay
# https://api.openweathermap.org/data/2.5/weather?q=dudinka&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 42 of Set 6 | dudinka
# https://api.openweathermap.org/data/2.5/weather?q=vigia&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 43 of Set 6 | vigia
# https://api.openweathermap.org/data/2.5/weather?q=husavik&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 44 of Set 6 | husavik
# https://api.openweathermap.org/data/2.5/weather?q=takoradi&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 45 of Set 6 | takoradi
# https://api.openweathermap.org/data/2.5/weather?q=inirida&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 46 of Set 6 | inirida
# https://api.openweathermap.org/data/2.5/weather?q=roald&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 47 of Set 6 | roald
# https://api.openweathermap.org/data/2.5/weather?q=katsuura&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 48 of Set 6 | katsuura
# https://api.openweathermap.org/data/2.5/weather?q=guerrero negro&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 49 of Set 6 | guerrero negro
# https://api.openweathermap.org/data/2.5/weather?q=bandarbeyla&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 0 of Set 7 | bandarbeyla
# https://api.openweathermap.org/data/2.5/weather?q=darhan&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 1 of Set 7 | darhan
# https://api.openweathermap.org/data/2.5/weather?q=ahipara&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 2 of Set 7 | ahipara
# https://api.openweathermap.org/data/2.5/weather?q=shache&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 3 of Set 7 | shache
# https://api.openweathermap.org/data/2.5/weather?q=mitu&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 4 of Set 7 | mitu
# https://api.openweathermap.org/data/2.5/weather?q=atar&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 5 of Set 7 | atar
# https://api.openweathermap.org/data/2.5/weather?q=vaitape&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 6 of Set 7 | vaitape
# https://api.openweathermap.org/data/2.5/weather?q=santa fe&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 7 of Set 7 | santa fe
# ...
# Processing Record 41 of Set 11 | colares
# https://api.openweathermap.org/data/2.5/weather?q=lodja&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 42 of Set 11 | lodja
# https://api.openweathermap.org/data/2.5/weather?q=desaguadero&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 43 of Set 11 | desaguadero
# https://api.openweathermap.org/data/2.5/weather?q=longyearbyen&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 44 of Set 11 | longyearbyen
# https://api.openweathermap.org/data/2.5/weather?q=dakar&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 45 of Set 11 | dakar
# https://api.openweathermap.org/data/2.5/weather?q=kazalinsk&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 46 of Set 11 | kazalinsk
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=kikwit&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 47 of Set 11 | kikwit
# https://api.openweathermap.org/data/2.5/weather?q=caravelas&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 48 of Set 11 | caravelas
# https://api.openweathermap.org/data/2.5/weather?q=dukat&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 49 of Set 11 | dukat
# https://api.openweathermap.org/data/2.5/weather?q=nagato&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 0 of Set 12 | nagato
# https://api.openweathermap.org/data/2.5/weather?q=pelham&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 1 of Set 12 | pelham
# https://api.openweathermap.org/data/2.5/weather?q=olafsvik&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 2 of Set 12 | olafsvik
# https://api.openweathermap.org/data/2.5/weather?q=kajaani&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 3 of Set 12 | kajaani
# https://api.openweathermap.org/data/2.5/weather?q=anloga&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 4 of Set 12 | anloga
# https://api.openweathermap.org/data/2.5/weather?q=falmouth&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 5 of Set 12 | falmouth
# https://api.openweathermap.org/data/2.5/weather?q=katherine&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 6 of Set 12 | katherine
# https://api.openweathermap.org/data/2.5/weather?q=kalmunai&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 7 of Set 12 | kalmunai
# https://api.openweathermap.org/data/2.5/weather?q=roebourne&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 8 of Set 12 | roebourne
# https://api.openweathermap.org/data/2.5/weather?q=richards bay&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 9 of Set 12 | richards bay
# https://api.openweathermap.org/data/2.5/weather?q=yumen&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 10 of Set 12 | yumen
# https://api.openweathermap.org/data/2.5/weather?q=ixtapa&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 11 of Set 12 | ixtapa
# https://api.openweathermap.org/data/2.5/weather?q=sapouy&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 12 of Set 12 | sapouy
# https://api.openweathermap.org/data/2.5/weather?q=seidu&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 13 of Set 12 | seidu
# https://api.openweathermap.org/data/2.5/weather?q=iberia&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 14 of Set 12 | iberia
# https://api.openweathermap.org/data/2.5/weather?q=chala&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 15 of Set 12 | chala
# https://api.openweathermap.org/data/2.5/weather?q=kapuskasing&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 16 of Set 12 | kapuskasing
# https://api.openweathermap.org/data/2.5/weather?q=green river&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 17 of Set 12 | green river
# https://api.openweathermap.org/data/2.5/weather?q=lujan&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 18 of Set 12 | lujan
# https://api.openweathermap.org/data/2.5/weather?q=howell&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 19 of Set 12 | howell
# https://api.openweathermap.org/data/2.5/weather?q=san francisco&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 20 of Set 12 | san francisco
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=nola&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 21 of Set 12 | nola
# https://api.openweathermap.org/data/2.5/weather?q=nizwa&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 22 of Set 12 | nizwa
# https://api.openweathermap.org/data/2.5/weather?q=mgarr&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 23 of Set 12 | mgarr
# https://api.openweathermap.org/data/2.5/weather?q=pimentel&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 24 of Set 12 | pimentel
# https://api.openweathermap.org/data/2.5/weather?q=ondorhaan&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 25 of Set 12 | ondorhaan
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=kandy&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 26 of Set 12 | kandy
# https://api.openweathermap.org/data/2.5/weather?q=huarmey&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 27 of Set 12 | huarmey
# https://api.openweathermap.org/data/2.5/weather?q=stokmarknes&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 28 of Set 12 | stokmarknes
# https://api.openweathermap.org/data/2.5/weather?q=tortoli&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 29 of Set 12 | tortoli
# https://api.openweathermap.org/data/2.5/weather?q=olinda&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 30 of Set 12 | olinda
# https://api.openweathermap.org/data/2.5/weather?q=monaghan&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 31 of Set 12 | monaghan
# https://api.openweathermap.org/data/2.5/weather?q=juneau&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 32 of Set 12 | juneau
# https://api.openweathermap.org/data/2.5/weather?q=den helder&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 33 of Set 12 | den helder
# https://api.openweathermap.org/data/2.5/weather?q=duluth&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 34 of Set 12 | duluth
# https://api.openweathermap.org/data/2.5/weather?q=borovskoy&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 35 of Set 12 | borovskoy
# https://api.openweathermap.org/data/2.5/weather?q=saint-georges&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 36 of Set 12 | saint-georges
# https://api.openweathermap.org/data/2.5/weather?q=the valley&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 37 of Set 12 | the valley
# https://api.openweathermap.org/data/2.5/weather?q=balgazyn&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 38 of Set 12 | balgazyn
# https://api.openweathermap.org/data/2.5/weather?q=gizo&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 39 of Set 12 | gizo
# https://api.openweathermap.org/data/2.5/weather?q=wonthaggi&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 40 of Set 12 | wonthaggi
# https://api.openweathermap.org/data/2.5/weather?q=santiago de cao&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 41 of Set 12 | santiago de cao
# https://api.openweathermap.org/data/2.5/weather?q=vila velha&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 42 of Set 12 | vila velha
# https://api.openweathermap.org/data/2.5/weather?q=yamada&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 43 of Set 12 | yamada
# https://api.openweathermap.org/data/2.5/weather?q=afmadu&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 44 of Set 12 | afmadu
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=ayagoz&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 45 of Set 12 | ayagoz
# https://api.openweathermap.org/data/2.5/weather?q=manaure&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 46 of Set 12 | manaure
# https://api.openweathermap.org/data/2.5/weather?q=zaysan&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 47 of Set 12 | zaysan
# https://api.openweathermap.org/data/2.5/weather?q=nautanwa&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 48 of Set 12 | nautanwa
# https://api.openweathermap.org/data/2.5/weather?q=petatlan&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 49 of Set 12 | petatlan
# https://api.openweathermap.org/data/2.5/weather?q=tezu&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 0 of Set 13 | tezu
# https://api.openweathermap.org/data/2.5/weather?q=achisay&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 1 of Set 13 | achisay
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=aleppo&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 2 of Set 13 | aleppo
# https://api.openweathermap.org/data/2.5/weather?q=polunochnoye&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 3 of Set 13 | polunochnoye
# https://api.openweathermap.org/data/2.5/weather?q=iskateley&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 4 of Set 13 | iskateley
# https://api.openweathermap.org/data/2.5/weather?q=colwyn bay&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 5 of Set 13 | colwyn bay
# https://api.openweathermap.org/data/2.5/weather?q=sataua&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 6 of Set 13 | sataua
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=irbil&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 7 of Set 13 | irbil
# https://api.openweathermap.org/data/2.5/weather?q=cabedelo&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 8 of Set 13 | cabedelo
# https://api.openweathermap.org/data/2.5/weather?q=kavaratti&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 9 of Set 13 | kavaratti
# https://api.openweathermap.org/data/2.5/weather?q=hihifo&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 10 of Set 13 | hihifo
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=turukhansk&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 11 of Set 13 | turukhansk
# https://api.openweathermap.org/data/2.5/weather?q=sompeta&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 12 of Set 13 | sompeta
# https://api.openweathermap.org/data/2.5/weather?q=bilibino&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 13 of Set 13 | bilibino
# https://api.openweathermap.org/data/2.5/weather?q=moshenskoye&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 14 of Set 13 | moshenskoye
# https://api.openweathermap.org/data/2.5/weather?q=mitsamiouli&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 15 of Set 13 | mitsamiouli
# https://api.openweathermap.org/data/2.5/weather?q=alice&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 16 of Set 13 | alice
# https://api.openweathermap.org/data/2.5/weather?q=chunskiy&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 17 of Set 13 | chunskiy
# https://api.openweathermap.org/data/2.5/weather?q=satitoa&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 18 of Set 13 | satitoa
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=tutoia&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 19 of Set 13 | tutoia
# https://api.openweathermap.org/data/2.5/weather?q=inderborskiy&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 20 of Set 13 | inderborskiy
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=carauari&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 21 of Set 13 | carauari
# https://api.openweathermap.org/data/2.5/weather?q=tiznit&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 22 of Set 13 | tiznit
# https://api.openweathermap.org/data/2.5/weather?q=kieta&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 23 of Set 13 | kieta
# https://api.openweathermap.org/data/2.5/weather?q=labuan&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 24 of Set 13 | labuan
# https://api.openweathermap.org/data/2.5/weather?q=moyamba&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 25 of Set 13 | moyamba
# https://api.openweathermap.org/data/2.5/weather?q=yerbogachen&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 26 of Set 13 | yerbogachen
# https://api.openweathermap.org/data/2.5/weather?q=romny&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 27 of Set 13 | romny
# https://api.openweathermap.org/data/2.5/weather?q=waitati&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 28 of Set 13 | waitati
# https://api.openweathermap.org/data/2.5/weather?q=roma&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 29 of Set 13 | roma
# https://api.openweathermap.org/data/2.5/weather?q=tigil&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 30 of Set 13 | tigil
# https://api.openweathermap.org/data/2.5/weather?q=casma&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 31 of Set 13 | casma
# https://api.openweathermap.org/data/2.5/weather?q=umm kaddadah&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 32 of Set 13 | umm kaddadah
# https://api.openweathermap.org/data/2.5/weather?q=panji&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 33 of Set 13 | panji
# https://api.openweathermap.org/data/2.5/weather?q=port-gentil&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 34 of Set 13 | port-gentil
# https://api.openweathermap.org/data/2.5/weather?q=huddersfield&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 35 of Set 13 | huddersfield
# https://api.openweathermap.org/data/2.5/weather?q=lata&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 36 of Set 13 | lata
# https://api.openweathermap.org/data/2.5/weather?q=tapaua&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 37 of Set 13 | tapaua
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=xiongshi&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 38 of Set 13 | xiongshi
# City not found. Skipping...
# https://api.openweathermap.org/data/2.5/weather?q=nauta&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 39 of Set 13 | nauta
# https://api.openweathermap.org/data/2.5/weather?q=tayginka&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 40 of Set 13 | tayginka
# https://api.openweathermap.org/data/2.5/weather?q=rapid valley&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 41 of Set 13 | rapid valley
# https://api.openweathermap.org/data/2.5/weather?q=ariquemes&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 42 of Set 13 | ariquemes
# https://api.openweathermap.org/data/2.5/weather?q=tuggurt&appid=25cbe733b5818eb3fec3338d511bcbf5&units=metric
# Processing Record 43 of Set 13 | tuggurt
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

city_data_df.head()

# Show Record Count
city_data_df.count()
# Out:
# City          583
# Lat           583
# Lng           583
# Max Temp      583
# Humidity      583
# Cloudiness    583
# Wind Speed    583
# Country       583
# Date          583
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity    Cloudiness  \
# 0             atuona  -9.8000 -139.0333     27.21        76   {'all': 59}
# 1            paciran  -6.8767  112.3761     26.58        83  {'all': 100}
# 2         mahibadhoo   3.7833   72.9667     27.29        76   {'all': 23}
# 3  sao joao da barra -21.6403  -41.0511     25.05        86   {'all': 64}
# 4            talnakh  69.4865   88.3972    -27.61       100  {'all': 100}
#
#    Wind Speed Country        Date
# 0        6.58      PF  1680133060
# 1        3.55      ID  1680133062
# 2        2.43      MV  1680133064
# 3        3.37      BR  1680133067
# 4        2.92      RU  1680133070

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

city_data_df["Cloudiness"] = (city_data_df["Cloudiness"]).str.replace("{'all':", "")
city_data_df["Cloudiness"] = (city_data_df["Cloudiness"]).str.replace("}", "")
# Display sample data
city_data_df.head()
# Out:
# /var/folders/c6/f4lv068572x0t6lvnvn2yjyc0000gn/T/ipykernel_93812/3256076365.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   city_data_df["Cloudiness"] = (city_data_df["Cloudiness"]).str.replace("{'all':", "")
# /var/folders/c6/f4lv068572x0t6lvnvn2yjyc0000gn/T/ipykernel_93812/3256076365.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   city_data_df["Cloudiness"] = (city_data_df["Cloudiness"]).str.replace("}", "")
#                       City      Lat       Lng  Max Temp  Humidity Cloudiness  \
# City_ID
# 0                   atuona  -9.8000 -139.0333     27.21        76         59
# 1                  paciran  -6.8767  112.3761     26.58        83        100
# 2               mahibadhoo   3.7833   72.9667     27.29        76         23
# 3        sao joao da barra -21.6403  -41.0511     25.05        86         64
# 4                  talnakh  69.4865   88.3972    -27.61       100        100
#
#          Wind Speed Country        Date
# City_ID
# 0              6.58      PF  1680133060
# 1              3.55      ID  1680133062
# 2              2.43      MV  1680133064
# 3              3.37      BR  1680133067
# 4              2.92      RU  1680133070

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
xaxis = pd.to_numeric(city_data_df["Lat"].astype(float))
yaxis = pd.to_numeric(city_data_df["Max Temp"].astype(float))

xaxis = city_data_df["Lat"]
yaxis = city_data_df["Max Temp"]
plt.scatter(xaxis, yaxis)

#Incorporate the other graph properties
plt.grid()
# plt.xlim(-58,85)
# plt.ylim(-25,45)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title("City Max Latitude vs. Temperature (2023-03-30)")

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
xaxis = city_data_df["Lat"]
yaxis = city_data_df["Humidity"]
plt.scatter(xaxis, yaxis)

# Incorporate the other graph properties
plt.grid()
plt.xlim(-58,85)
plt.ylim(0,110)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity (2023-03-30)")

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
xaxis = city_data_df["Lat"]
yaxis = pd.to_numeric(city_data_df["Cloudiness"].astype(float))
plt.scatter(xaxis, yaxis)

# Incorporate the other graph properties
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness (2023-03-30)")

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
xaxis = city_data_df["Lat"]
yaxis = city_data_df["Wind Speed"]
plt.scatter(xaxis, yaxis)

# Incorporate the other graph properties
plt.grid()
plt.xlim(-58,85)
plt.ylim(-5,20)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title("City Latitude vs. Windspeed (2023-03-30)")

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regression(x,y):  
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    regression = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    # Create a dictionary containing the regression parameters
    regression_dictionary = {'slope': slope, 'intercept': intercept, 'rvalue': rvalue, 'pvalue': pvalue, 'stderr': stderr, "regress_values" : regress_values, "regression": regression}
    
    return regression_dictionary

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]).astype(float) >= 0, :]
# Display sample data
northern_hemi_df.head()
#northern_hemi_df.count()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity Cloudiness  \
# City_ID
# 2           mahibadhoo   3.7833   72.9667     27.29        76         23
# 4              talnakh  69.4865   88.3972    -27.61       100        100
# 7        half moon bay  37.4636 -122.4286     11.68        85        100
# 8                tiksi  71.6872  128.8694    -26.32        98         74
# 12                abha  18.2164   42.5053     15.14        82          0
#
#          Wind Speed Country        Date
# City_ID
# 2              2.43      MV  1680133064
# 4              2.92      RU  1680133070
# 7              4.63      US  1680133075
# 8              2.12      RU  1680133139
# 12             3.09      SA  1680133105

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]).astype(float) < 0, :]
# Display sample data
southern_hemi_df.head()
#southern_hemi_df.count()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity Cloudiness  \
# City_ID
# 0                   atuona  -9.8000 -139.0333     27.21        76         59
# 1                  paciran  -6.8767  112.3761     26.58        83        100
# 3        sao joao da barra -21.6403  -41.0511     25.05        86         64
# 5           port elizabeth -33.9180   25.5701     16.16        69          0
# 6                busselton -33.6500  115.3333     17.06        69         95
#
#          Wind Speed Country        Date
# City_ID
# 0              6.58      PF  1680133060
# 1              3.55      ID  1680133062
# 3              3.37      BR  1680133067
# 5              9.26      ZA  1680132982
# 6              6.86      AU  1680132826

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x = pd.to_numeric(northern_hemi_df['Lat']).astype(float)
y = pd.to_numeric(northern_hemi_df['Max Temp']).astype(float)

#the equation
linear_regression(x,y)  

# Regression plot
regression_dict = linear_regression(x, y)
plt.scatter(x,y, color = "c", label = "Original Data")
plt.plot(x,regression_dict['regress_values'], color="b", label = "Regression Analysis")

# Regression format
plt.annotate(regression_dict['regression'],(10,-20),fontsize=15,color="b")
plt.annotate("R-value: {:.4f}".format(regression_dict['rvalue']), (10, -25), fontsize=10, color="b")
plt.title("Northern Hemisphere - Max Temp vs Latitude as at 30 March 2023")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (C)")
plt.legend()
plt.show()

# Regression summary
print(f"Discussion about linear relationships:")
print(f"------------------------------------------------------------------------------")
print(f"For the Northern Hemisphere the Max Temp vs. Latitude linear regression is: {regression_dict['regression']}")
print(f"The R value is: {regression_dict['rvalue']}, the regression details a strong correlation")
print(f"The regression and the R-value details a relatively strong-negative correlation, this therefore implies that cities that lie further north of the equator have colder climates")
# Out:
# Discussion about linear relationships:
# ------------------------------------------------------------------------------
# For the Northern Hemisphere the Max Temp vs. Latitude linear regression is: y = -0.62x + 33.23
# The R value is: -0.8964684104778592, the regression details a strong correlation
# The regression and the R-value details a relatively strong-negative correlation, this therefore implies that cities that lie further north of the equator have colder climates

# %%
# Linear regression on Southern Hemisphere
x = pd.to_numeric(southern_hemi_df['Lat']).astype(float)
y = pd.to_numeric(southern_hemi_df['Max Temp']).astype(float)
# print(x)
# print(y)

#the equation
linear_regression(x, y)

# Regression plot
regression_dict = linear_regression(x, y)
plt.scatter(x,y, color = "c", label = "Original Data")
plt.plot(x,regression_dict['regress_values'], color="b", label = "Regression Analysis")

# Regression format
plt.annotate(regression_dict['regression'],(-40,5),fontsize=15,color="b")
plt.annotate("R-value: {:.4f}".format(regression_dict['rvalue']), (-40,3), fontsize=10, color="b")
plt.title("Southern Hemisphere - Max Temp vs Latitude as at 30 March 2023")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (C)")
plt.legend()
plt.show()

# Regression summary
print(f"Discussion about linear relationships:")
print(f"------------------------------------------------------------------------------")
print(f"For the Southern Hemisphere the Max Temp vs. Latitude linear regression is: {regression_dict['regression']}")
print(f"The R value is: {regression_dict['rvalue']}, the regression details a medium correlation")
print(f"The regression and the R-value details a relatively medium positive correlation, this therefore implies that generally cities that lie futher south of the equater have colder climates")
# Out:
# Discussion about linear relationships:
# ------------------------------------------------------------------------------
# For the Southern Hemisphere the Max Temp vs. Latitude linear regression is: y = 0.3x + 27.8
# The R value is: 0.678588540894453, the regression details a medium correlation
# The regression and the R-value details a relatively medium positive correlation, this therefore implies that generally cities that lie futher south of the equater have colder climates

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x = pd.to_numeric(northern_hemi_df['Lat']).astype(float)
y = pd.to_numeric(northern_hemi_df['Humidity']).astype(float)

#the equation
linear_regression(x, y)

# Regression plot
regression_dict = linear_regression(x, y)
plt.scatter(x,y, color = "c", label = "Original Data")
plt.plot(x,regression_dict['regress_values'], color="b", label = "Regression Analysis")

# Regression format
#regression format
plt.annotate(regression_dict['regression'],(45,30),fontsize=15,color="b")
plt.annotate("R-value: {:.4f}".format(regression_dict['rvalue']), (45, 25), fontsize=10, color="b")
plt.title("Northern Hemisphere - Humidity vs Latitude as at 30 March 2023")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.legend()
plt.show()

#summary
print(f"Discussion about linear relationships:")
print(f"------------------------------------------------------------------------------")
print(f"For the Northern Hemisphere the Humidity vs. Latitude linear regression is: {regression_dict['regression']}")
print(f"The R value is: {regression_dict['rvalue']}, the regression details a weak correlation")
print(f"The regression and the R-value details a relatively weak positive correlation, therefore implying that regardless of how far cities lie north of the equater humidity remains relatively unaffected")
# Out:
# Discussion about linear relationships:
# ------------------------------------------------------------------------------
# For the Northern Hemisphere the Humidity vs. Latitude linear regression is: y = 0.24x + 62.04
# The R value is: 0.21328713494116983, the regression details a weak correlation
# The regression and the R-value details a relatively weak positive correlation, therefore implying that regardless of how far cities lie north of the equater humidity remains relatively unaffected

# %%
# Southern Hemisphere
x = pd.to_numeric(southern_hemi_df['Lat']).astype(float)
y = pd.to_numeric(southern_hemi_df['Humidity']).astype(float)

#the equation
linear_regression(x, y)

# Regression plot
regression_dict = linear_regression(x, y)
plt.scatter(x,y, color = "c", label = "Original Data")
plt.plot(x,regression_dict['regress_values'], color="b", label = "Regression Analysis")
plt.legend

#regression format
plt.annotate(regression_dict['regression'],(-50,30),fontsize=15,color="b")
plt.annotate("R-value: {:.4f}".format(regression_dict['rvalue']), (-50,95), fontsize=10, color="b")
plt.title("Southern Hemisphere - Humidity vs Latitude as at 30 March 2023")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.legend()
plt.show()

#summary
print(f"Discussion about linear relationships:")
print(f"------------------------------------------------------------------------------")
print(f"For the Southern Hemisphere the Humidity vs. Latitude linear regression is: {regression_dict['regression']}")
print(f"The R value is: {regression_dict['rvalue']}, the regression details a weak correlation")
print(f"The regression and the R-value details a relatively weak positive correlation, this therefore implies that cities that lie futher south of the equater generally have lower levels of humidity")
# Out:
# Discussion about linear relationships:
# ------------------------------------------------------------------------------
# For the Southern Hemisphere the Humidity vs. Latitude linear regression is: y = 0.49x + 86.99
# The R value is: 0.4559293577921491, the regression details a weak correlation
# The regression and the R-value details a relatively weak positive correlation, this therefore implies that cities that lie futher south of the equater generally have lower levels of humidity

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x = pd.to_numeric(northern_hemi_df['Lat']).astype(float)
y = pd.to_numeric(northern_hemi_df['Cloudiness']).astype(float)

#the equation
linear_regression(x, y)

# Regression plot
regression_dict = linear_regression(x, y)
plt.scatter(x,y, color = "c", label = "Original Data")
plt.plot(x,regression_dict["regress_values"],"r-", color="b", label = "Regression Analysis")
plt.legend()

#regression format
plt.annotate(regression_dict["regression"],(20,15),fontsize=15,color="b")
plt.annotate("R-value: {:.4f}".format(regression_dict["rvalue"]), (20, 10), fontsize=10, color="b")
plt.title("Northern Hemisphere - Cloudiness vs Latitude as at 30 March 2023")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.show()

#summary
print(f"Discussion about linear relationships:")
print(f"------------------------------------------------------------------------------")

print(f"For the Northern Hemisphere the 'Cloudiness' vs. Latitude linear regression is: {regression_dict['regression']}")
print(f"The R value is: {regression_dict['rvalue']}, the regression details a very weak correlation")
print(f"The regression and the R-value details a very weak positive correlation, therefore implying that regardless of how far cities lie north of the equater 'Cloudiness' remains relatively unaffected")
# Out:
# /var/folders/c6/f4lv068572x0t6lvnvn2yjyc0000gn/T/ipykernel_93812/38955703.py:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(x,regression_dict["regress_values"],"r-", color="b", label = "Regression Analysis")
# Discussion about linear relationships:
# ------------------------------------------------------------------------------
# For the Northern Hemisphere the 'Cloudiness' vs. Latitude linear regression is: y = 0.35x + 45.92
# The R value is: 0.18692799442256078, the regression details a very weak correlation
# The regression and the R-value details a very weak positive correlation, therefore implying that regardless of how far cities lie north of the equater 'Cloudiness' remains relatively unaffected

# %%
# Southern Hemisphere
x = pd.to_numeric(southern_hemi_df['Lat']).astype(float)
y = pd.to_numeric(southern_hemi_df['Cloudiness']).astype(float)

#the equation
linear_regression(x, y)

# Regression plot
regression_dict = linear_regression(x, y)
plt.scatter(x,y, color = "c", label = "Original Data")
plt.plot(x,regression_dict["regress_values"],"r-", color="b", label = "Regression Analysis")
plt.legend()

#regression format
plt.annotate(regression_dict["regression"],(-55,13),fontsize=15,color="b")
plt.annotate("R-value: {:.4f}".format(regression_dict["rvalue"]), (-15, 5), fontsize=10, color="b")
plt.title("Southern Hemisphere - Cloudiness vs Latitude as at 30 March 2023")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.show()

#summary
print(f"Discussion about linear relationships:")
print(f"------------------------------------------------------------------------------")

print(f"For the Southern Hemisphere the 'Cloudiness' vs. Latitude linear regression is: {regression_dict['regression']}")
print(f"The R value is: {regression_dict['rvalue']}, the regression details a very weak correlation")
print(f"The regression and the R-value details a very weak positive correlation, therefore implying that regardless of how far cities lie south of the equater 'Cloudiness' remains relatively unaffected")
# Out:
# /var/folders/c6/f4lv068572x0t6lvnvn2yjyc0000gn/T/ipykernel_93812/1500205574.py:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(x,regression_dict["regress_values"],"r-", color="b", label = "Regression Analysis")
# Discussion about linear relationships:
# ------------------------------------------------------------------------------
# For the Southern Hemisphere the 'Cloudiness' vs. Latitude linear regression is: y = 0.59x + 76.15
# The R value is: 0.23811919224966055, the regression details a very weak correlation
# The regression and the R-value details a very weak positive correlation, therefore implying that regardless of how far cities lie south of the equater 'Cloudiness' remains relatively unaffected

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x = pd.to_numeric(northern_hemi_df['Lat']).astype(float)
y = pd.to_numeric(northern_hemi_df['Wind Speed']).astype(float)

#the equation
linear_regression(x, y)

# Regression plot
regression_dict = linear_regression(x, y)
plt.scatter(x,y, color = "c", label = "Original Data")
plt.plot(x,regression_dict["regress_values"],"r-", color="b", label = "Regression Analysis")
plt.legend()

#regression format
plt.annotate(regression_dict["regression"],(20,13),fontsize=15,color="b")
plt.annotate("R-value: {:.4f}".format(regression_dict["rvalue"]), (20, 11.5), fontsize=10, color="b")
plt.title("Northern Hemisphere - Cloudiness vs Latitude as at 30 March 2023")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.show()

#summary
print(f"Discussion about linear relationships:")
print(f"------------------------------------------------------------------------------")

print(f"For the Northern Hemisphere the 'Wind Speed' vs. Latitude linear regression is: {regression_dict['regression']}")
print(f"The R value is: {regression_dict['rvalue']}, the regression details a very weak correlation")
print(f"The regression and the R-value details a very weak positive correlation, therefore implying that regardless of how far cities lie north of the equater 'Cloudiness' remains relatively unaffected")
# Out:
# /var/folders/c6/f4lv068572x0t6lvnvn2yjyc0000gn/T/ipykernel_93812/1324798143.py:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(x,regression_dict["regress_values"],"r-", color="b", label = "Regression Analysis")
# Discussion about linear relationships:
# ------------------------------------------------------------------------------
# For the Northern Hemisphere the 'Wind Speed' vs. Latitude linear regression is: y = 0.02x + 2.77
# The R value is: 0.15896639467679283, the regression details a very weak correlation
# The regression and the R-value details a very weak positive correlation, therefore implying that regardless of how far cities lie north of the equater 'Cloudiness' remains relatively unaffected

# %%
# Southern Hemisphere
x = pd.to_numeric(southern_hemi_df['Lat']).astype(float)
y = pd.to_numeric(southern_hemi_df['Wind Speed']).astype(float)

#the equation
linear_regression(x, y)

# Regression plot
regression_dict = linear_regression(x, y)
plt.scatter(x,y, color = "c", label = "Original Data")
plt.plot(x,regression_dict["regress_values"],"r-", color="b", label = "Regression Analysis")
plt.legend()

#regression format
plt.annotate(regression_dict["regression"],(-24,8),fontsize=15,color="b")
plt.annotate("R-value: {:.4f}".format(regression_dict["rvalue"]), (-24, 7), fontsize=10, color="b")
plt.title("Southern Hemisphere - Cloudiness vs Latitude as at 30 March 2023")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.show()

#summary
print(f"Discussion about linear relationships:")
print(f"------------------------------------------------------------------------------")

print(f"For the Southern Hemisphere the 'Wind Speed' vs. Latitude linear regression is: {regression_dict['regression']}")
print(f"The R value is: {regression_dict['rvalue']}, the regression details a weak correlation")
print(f"The regression and the R-value details a relatively weak negative correlation, therefore implying that regardless of how far cities lie south of the equater 'Cloudiness' remains relatively unaffected")
# Out:
# /var/folders/c6/f4lv068572x0t6lvnvn2yjyc0000gn/T/ipykernel_93812/186049854.py:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(x,regression_dict["regress_values"],"r-", color="b", label = "Regression Analysis")
# Discussion about linear relationships:
# ------------------------------------------------------------------------------
# For the Southern Hemisphere the 'Wind Speed' vs. Latitude linear regression is: y = -0.07x + 1.65
# The R value is: -0.46883455413194747, the regression details a weak correlation
# The regression and the R-value details a relatively weak negative correlation, therefore implying that regardless of how far cities lie south of the equater 'Cloudiness' remains relatively unaffected
