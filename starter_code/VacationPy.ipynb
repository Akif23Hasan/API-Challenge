# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import os

# Import API key
#from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
csv_file = Path("../output_data/cities.csv")
city_data_df = pd.read_csv(csv_file)

# Display sample data
city_data_df["Cloudiness"] = (city_data_df["Cloudiness"]).str.replace("{'all':", "")
city_data_df["Cloudiness"] = (city_data_df["Cloudiness"]).str.replace("}", "")
city_data_df["City"] = city_data_df["City"].str.title()
city_data_df.head()
# Out:
# /var/folders/c6/f4lv068572x0t6lvnvn2yjyc0000gn/T/ipykernel_94587/318635296.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   city_data_df["Cloudiness"] = (city_data_df["Cloudiness"]).str.replace("{'all':", "")
# /var/folders/c6/f4lv068572x0t6lvnvn2yjyc0000gn/T/ipykernel_94587/318635296.py:7: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   city_data_df["Cloudiness"] = (city_data_df["Cloudiness"]).str.replace("}", "")
#    City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0        0             Atuona  -9.8000 -139.0333     27.21        76
# 1        1            Paciran  -6.8767  112.3761     26.58        83
# 2        2         Mahibadhoo   3.7833   72.9667     27.29        76
# 3        3  Sao Joao Da Barra -21.6403  -41.0511     25.05        86
# 4        4            Talnakh  69.4865   88.3972    -27.61       100
#
#   Cloudiness  Wind Speed Country        Date
# 0         59        6.58      PF  1680133060
# 1        100        3.55      ID  1680133062
# 2         23        2.43      MV  1680133064
# 3         64        3.37      BR  1680133067
# 4        100        2.92      RU  1680133070

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
#storing humidity as float tyope for the following plot
humidity = city_data_df["Humidity"].astype(float)

# Configure the map plot
map_plot_humidity = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "EsriImagery",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    scale = 0.5,
    color = "City",
    title = "City Humidity Heatmap"    
)

# Display the map plot
map_plot_humidity
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
#Store Cloudiness as int64
city_data_df["Cloudiness"] = city_data_df["Cloudiness"].astype("Int64")

# Narrow down cities that fit criteria and drop any results with null values
narrow_df = city_data_df.loc[(city_data_df["Max Temp"] < 30) & (city_data_df["Max Temp"] > 25) & (city_data_df["Cloudiness"] < 15) & (city_data_df["Wind Speed"] < 15)]

# Drop any rows with null values
narrow_df.dropna()

# Display sample data
narrow_df.head()
# Out:
#     City_ID                    City      Lat       Lng  Max Temp  Humidity  \
# 29       29                    Puri  19.8000   85.8500     26.29        85
# 47       47          Port Macquarie -31.4333  152.9167     26.05        39
# 53       53         Arraial Do Cabo -22.9661  -42.0278     25.92        83
# 86       86         Charters Towers -20.1000  146.2667     28.34        56
# 95       95  Santa Cruz De Tenerife  28.4682  -16.2546     25.17        17
#
#     Cloudiness  Wind Speed Country        Date
# 29           7        7.10      IN  1680133013
# 47           0        3.91      AU  1680133200
# 53           0        5.14      BR  1680133209
# 86           6        4.43      AU  1680133260
# 95           0        0.51      ES  1680133276

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = city_data_df[["City", "Country", "Lat", "Lng", "Humidity"]]

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df.head()
# Out:
# /var/folders/c6/f4lv068572x0t6lvnvn2yjyc0000gn/T/ipykernel_94587/572696565.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_df["Hotel Name"] = ""
#                 City Country      Lat       Lng  Humidity Hotel Name
# 0             Atuona      PF  -9.8000 -139.0333        76
# 1            Paciran      ID  -6.8767  112.3761        83
# 2         Mahibadhoo      MV   3.7833   72.9667        76
# 3  Sao Joao Da Barra      BR -21.6403  -41.0511        86
# 4            Talnakh      RU  69.4865   88.3972       100

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = { 
    "categories": "accommodation.hotel",
    "apiKey": geoapify_key,
    "limit":20
 }

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    
    # Get the city's name
    city = row["City"]
    
    # Get latitude, longitude from the DataFrame
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places?"
   
    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()

    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

#Display sample data
hotel_df
# Out:
# Starting hotel search
# atuona - nearest hotel: Pearl Resort
# paciran - nearest hotel: No hotel found
# mahibadhoo - nearest hotel: Coral View Inn
# sao joao da barra - nearest hotel: Pousada Mediterrâneo
# talnakh - nearest hotel: Талнах
# port elizabeth - nearest hotel: Waterford Hotel
# busselton - nearest hotel: Broadwater Beach Resort
# half moon bay - nearest hotel: Half Moon Bay Inn
# tiksi - nearest hotel: Арктика
# werda - nearest hotel: No hotel found
# sao paulo de olivenca - nearest hotel: No hotel found
# avarua - nearest hotel: Paradise Inn
# abha - nearest hotel: SAHAB
# torbay - nearest hotel: Hampton
# hithadhoo - nearest hotel: Pebbles Inn
# port alfred - nearest hotel: No hotel found
# barybino - nearest hotel: Мастер отель Домодедово
# oxford - nearest hotel: Old Bank Hotel
# xifeng - nearest hotel: No hotel found
# albany - nearest hotel: No hotel found
# mahebourg - nearest hotel: Grand Bel Air
# punta arenas - nearest hotel: Hotel Lacolet
# rikitea - nearest hotel: Chez Bianca & Benoit
# alingsas - nearest hotel: First Hotel Grand
# vaini - nearest hotel: Keleti International Resort
# hilo - nearest hotel: Dolphin Bay Hotel
# shaoguan - nearest hotel: Holiday Inn Shaoguan Downtown
# carnarvon - nearest hotel: No hotel found
# sola - nearest hotel: No hotel found
# puri - nearest hotel: Divine Beach Homestay
# nenjiang - nearest hotel: No hotel found
# sitka - nearest hotel: Aspen Suites Hotel
# tuktoyaktuk - nearest hotel: Hunter's B&B
# rocha - nearest hotel: Hotel Municipal
# kapaa - nearest hotel: Pono Kai Resort
# ribeira grande - nearest hotel: Hospedaria JSF - 3 Estrelas
# yellowknife - nearest hotel: No hotel found
# cape town - nearest hotel: Townhouse Hotel
# hermanus - nearest hotel: Aloe guest house
# qaanaaq - nearest hotel: Hotel Qaanaaq
# waipawa - nearest hotel: No hotel found
# camopi - nearest hotel: Chez Lucia
# bluff - nearest hotel: No hotel found
# villa maria - nearest hotel: Gran Hotel Orión
# mataura - nearest hotel: No hotel found
# lebu - nearest hotel: No hotel found
# yulara - nearest hotel: Outback Pioneer Hotel & Lodge
# port macquarie - nearest hotel: The Observatory
# maputo - nearest hotel: Mozaika
# mugur-aksy - nearest hotel: No hotel found
# aykhal - nearest hotel: Уют
# aksarka - nearest hotel: No hotel found
# saint-augustin - nearest hotel: No hotel found
# arraial do cabo - nearest hotel: No hotel found
# tromso - nearest hotel: Clarion Collection Hotel Aurora
# mpanda - nearest hotel: Two in One Kirari Executive Lodge
# conceicao da barra - nearest hotel: Porto Marlin Hotel
# gwembe - nearest hotel: No hotel found
# huntington - nearest hotel: Delta
# fayetteville - nearest hotel: Regency Inn
# hobart - nearest hotel: Vibe Hotel Hobart
# georgetown - nearest hotel: Page 63 hostel
# kasongo-lunda - nearest hotel: No hotel found
# neyshabur - nearest hotel: هتل امیران
# grindavik - nearest hotel: The Retreat at Blue Lagoon Iceland
# flin flon - nearest hotel: Copperbelt Hotel
# lac du bonnet - nearest hotel: Casey's Inn Motor Hotel
# okhotsk - nearest hotel: No hotel found
# kamaishi - nearest hotel: 釜石ベイシティホテル
# aklavik - nearest hotel: No hotel found
# barcelona - nearest hotel: Cram
# barrow - nearest hotel: No hotel found
# ushuaia - nearest hotel: Apart Hotel Aires del Beagle
# narsaq - nearest hotel: Hotel Narsaq
# gat - nearest hotel: No hotel found
# toumodi - nearest hotel: Allou Hôtel
# upernavik - nearest hotel: No hotel found
# yar-sale - nearest hotel: ЯЛЭМД
# oudtshoorn - nearest hotel: The Pearl
# evensk - nearest hotel: No hotel found
# hay river - nearest hotel: No hotel found
# port lincoln - nearest hotel: Boston Hotel
# chuy - nearest hotel: Alerces
# norman wells - nearest hotel: Yamouri Inn
# neyyattinkara - nearest hotel: Mini Hotel
# nova odesa - nearest hotel: Готель Круїз
# charters towers - nearest hotel: No hotel found
# east london - nearest hotel: No hotel found
# zhigansk - nearest hotel: ИП Пав
# airai - nearest hotel: No hotel found
# geelong - nearest hotel: Nireeda
# atambua - nearest hotel: Hotel Matahari
# kruisfontein - nearest hotel: No hotel found
# thompson - nearest hotel: Thompson Inn
# port hawkesbury - nearest hotel: Hearthstone Inn Port Hawkesbury
# santa cruz de tenerife - nearest hotel: Hotel Príncipe Paz
# joshimath - nearest hotel: Snow Crest Hotel
# paamiut - nearest hotel: Hotel Ivaana
# bathsheba - nearest hotel: Atlantis Hotel
# togur - nearest hotel: Визит
# iqaluit - nearest hotel: Frobisher Inn
# honiara - nearest hotel: King Solomon Hotel
# butaritari - nearest hotel: No hotel found
# puerto ayora - nearest hotel: Hostal La Mirada De Solitario George
# ekibastuz - nearest hotel: General
# cabo san lucas - nearest hotel: Comfort Rooms
# souillac - nearest hotel: Hotel SkylineInn
# tres coracoes - nearest hotel: Hotel Avenida
# khatanga - nearest hotel: Хатанга
# peterhead - nearest hotel: Albert Hotel
# hudiksvall - nearest hotel: Best Western Hotel Hudik
# domat - nearest hotel: Schlosshotel Adler
# hambantota - nearest hotel: Oasis Aurweda Resort Hambathota
# ukiah - nearest hotel: Palace Hotel
# anupgarh - nearest hotel: Hotel Namish
# severo-kurilsk - nearest hotel: "Дом рыбака"
# chokurdakh - nearest hotel: No hotel found
# kijang - nearest hotel: 힐튼호텔 부산
# saint george - nearest hotel: The Advenire, an Autograph Collection Hotel
# saskylakh - nearest hotel: No hotel found
# dunedin - nearest hotel: Scenic Hotel Dunedin City
# sao filipe - nearest hotel: Bela Vista
# penzance - nearest hotel: The Abbey Hotel
# northam - nearest hotel: Durrant House Hotel
# strezhevoy - nearest hotel: Гостиница "Сибирячка"
# mandera - nearest hotel: Kornesh Hotel and Lodging
# jamestown - nearest hotel: DoubleTree Jamestown
# arlit - nearest hotel: No hotel found
# eston - nearest hotel: No hotel found
# mogadishu - nearest hotel: Villa Rays Restaurant & Hotel
# pevek - nearest hotel: No hotel found
# kodiak - nearest hotel: Shelikof Lodge
# gorur - nearest hotel: No hotel found
# riacho de santana - nearest hotel: No hotel found
# lichuan - nearest hotel: No hotel found
# new norfolk - nearest hotel: Woodbridge on the Derwent
# alofi - nearest hotel: Matavai Resort
# tautira - nearest hotel: No hotel found
# uruzgan - nearest hotel: No hotel found
# namibe - nearest hotel: Hotel Chik Chik Namibe
# cidreira - nearest hotel: Hotel Castelo
# belyy yar - nearest hotel: No hotel found
# sinnamary - nearest hotel: Hôtel du fleuve
# beloha - nearest hotel: Hôtel Oliv
# mayor pablo lagerenza - nearest hotel: No hotel found
# hofn - nearest hotel: Guesthouse Dyngja
# teahupoo - nearest hotel: Vanira Lodge
# vila franca do campo - nearest hotel: Vinha d'Areia Beach Hotel
# kosh-agach - nearest hotel: Заря
# ocampo - nearest hotel: No hotel found
# atikokan - nearest hotel: No hotel found
# yatou - nearest hotel: No hotel found
# san joaquin - nearest hotel: I-5 Inn
# alta floresta - nearest hotel: Villas Hotel
# jining - nearest hotel: No hotel found
# smithers - nearest hotel: Sunshine Inn Hotel
# turayf - nearest hotel: Al-Mudwah
# khuzdar - nearest hotel: Al-Mustafa hotel
# tsaratanana - nearest hotel: No hotel found
# japura - nearest hotel: No hotel found
# rawson - nearest hotel: Hotel Deportivo
# mount gambier - nearest hotel: The Old Mount Gambier Gaol
# henties bay - nearest hotel: Huis Klipdrift
# inhambane - nearest hotel: Hotel de Inhambane
# ancud - nearest hotel: Cabañas
# sao joao do piaui - nearest hotel: Hotel Esplanada
# cherskiy - nearest hotel: No hotel found
# poltavka - nearest hotel: No hotel found
# dikson - nearest hotel: No hotel found
# bengkulu - nearest hotel: Dena Hotel
# ystad - nearest hotel: Hotell Prins Carl
# geraldton - nearest hotel: Ocean Centre Hotel
# lima - nearest hotel: Hotel Peach Garden
# daru - nearest hotel: Kuki
# selikhino - nearest hotel: No hotel found
# bedele - nearest hotel: No hotel found
# monrovia - nearest hotel: Bella Casa Hotel
# angola - nearest hotel: No hotel found
# lasa - nearest hotel: Hotel "Drei Kreuz"
# requena - nearest hotel: Hotel Avenida
# pangkalanbuun - nearest hotel: Hotel Tiara
# nakamura - nearest hotel: ホテルココモ
# fare - nearest hotel: hôtel Maitai Lapita Village
# saint-francois - nearest hotel: Chez Lily
# ponta do sol - nearest hotel: Estalagem Ponta do Sol
# codrington - nearest hotel: No hotel found
# hammerfest - nearest hotel: Thon Hotel Hammerfest
# tshikapa - nearest hotel: Hôtel TSHAMUNTU
# namwala - nearest hotel: No hotel found
# padang - nearest hotel: losmen Surya
# mar del plata - nearest hotel: Nuevo Ostende
# loding - nearest hotel: Saltstraumen Hotel
# sabha - nearest hotel: فندق الكاظم-سبها
# solnechnyy - nearest hotel: Заря
# nanortalik - nearest hotel: Kap Farvel
# kaeo - nearest hotel: No hotel found
# castro - nearest hotel: Hotel Central Palace
# saint-philippe - nearest hotel: Le Baril
# komsomolskiy - nearest hotel: Hotel "Ikat House"
# constitucion - nearest hotel: Hostal Alameda
# amapa - nearest hotel: No hotel found
# stornoway - nearest hotel: County Hotel
# kibala - nearest hotel: فندق سفاري
# sechura - nearest hotel: Hospedaje Claritza
# trinidad - nearest hotel: Hotel Palace
# sobolevo - nearest hotel: No hotel found
# bure - nearest hotel: belay zeleke hotel
# bilma - nearest hotel: No hotel found
# kulevcha - nearest hotel: No hotel found
# bredasdorp - nearest hotel: Victoria Hotel
# makakilo city - nearest hotel: Embassy Suites by Hilton Oahu Kapolei
# laguna - nearest hotel: Holiday Inn Express & Suites
# broome - nearest hotel: No hotel found
# pisco - nearest hotel: La Portada
# kholm - nearest hotel: No hotel found
# korla - nearest hotel: Silver Star Hotel
# xinglongshan - nearest hotel: No hotel found
# timberlake - nearest hotel: Tru by Hilton Lynchburg
# listvyagi - nearest hotel: No hotel found
# tuatapere - nearest hotel: No hotel found
# itanhandu - nearest hotel: Hotel Casarão
# dong hoi - nearest hotel: Nhà hàng Amor Palace
# manggar - nearest hotel: No hotel found
# phalaborwa - nearest hotel: Hans Merensky Hotel & Estate
# pafos - nearest hotel: Mayfair Hotel
# tingi - nearest hotel: No hotel found
# poso - nearest hotel: Nusantara
# puerto cabezas - nearest hotel: Hotel Caribe
# beringovskiy - nearest hotel: No hotel found
# vardo - nearest hotel: Meieriet
# lompoc - nearest hotel: Embassy Suites by Hilton Lompoc Central Coast
# gamba - nearest hotel: No hotel found
# nacozari - nearest hotel: No hotel found
# mahina - nearest hotel: Motu Martin
# lavrentiya - nearest hotel: Фортуна
# batemans bay - nearest hotel: Esplanade Hotel
# kirkuk - nearest hotel: No hotel found
# ponta delgada - nearest hotel: Hotel Talisman
# mehamn - nearest hotel: Mehamn Arctic hotell
# marsa matruh - nearest hotel: صقور
# provideniya - nearest hotel: No hotel found
# panaba - nearest hotel: No hotel found
# esil - nearest hotel: Рахат
# valdivia - nearest hotel: Esmeralda
# hai duong - nearest hotel: PHUONG ANH HOTEL
# ust-omchug - nearest hotel: No hotel found
# pangody - nearest hotel: Газпром энерго
# makokou - nearest hotel: No hotel found
# bongandanga - nearest hotel: No hotel found
# tasiilaq - nearest hotel: Angmagssalik
# quarai - nearest hotel: Hotel União
# bethel - nearest hotel: Hampton Inn Danbury
# hokitika - nearest hotel: Beachfront Hotel
# sioux lookout - nearest hotel: Wellington Inn & Restaurant
# sibu - nearest hotel: The Paramount Hotel
# karatau - nearest hotel: Артабас
# coquimbo - nearest hotel: Hotel Iberia
# ballina - nearest hotel: Ballina Beach Resort
# pangnirtung - nearest hotel: Auyuittuq Lodge
# grand-lahou - nearest hotel: Cap Lahou
# wajid - nearest hotel: No hotel found
# nikolskoye - nearest hotel: No hotel found
# volokolamsk - nearest hotel: No hotel found
# byron bay - nearest hotel: Lord Byron Resort
# dudinka - nearest hotel: Виктория
# vigia - nearest hotel: No hotel found
# husavik - nearest hotel: Fosshótel Húsavík
# takoradi - nearest hotel: Hillcrest
# inirida - nearest hotel: Residencias El Turista del Guainia
# roald - nearest hotel: Vigra fjordhotell
# katsuura - nearest hotel: 潮騒の宿
# guerrero negro - nearest hotel: Plaza sal paraiso
# bandarbeyla - nearest hotel: No hotel found
# darhan - nearest hotel: Алтан зочид буудал
# ahipara - nearest hotel: YHA Ahipara
# shache - nearest hotel: 莎車新盛賓舘
# mitu - nearest hotel: Hotel Brasilia Vaupés
# atar - nearest hotel: فندق سكليل
# vaitape - nearest hotel: Oa Oa Lodge
# santa fe - nearest hotel: Intersur Hotel
# canarana - nearest hotel: No hotel found
# zhangjiakou - nearest hotel: 商务宾馆
# dauphin - nearest hotel: No hotel found
# adrar - nearest hotel: No hotel found
# perez - nearest hotel: Del Paseo
# kavieng - nearest hotel: Kavieng Hotel
# luderitz - nearest hotel: Seaview Hotel Zum Sperrgebiet
# ust-ishim - nearest hotel: Иртыш
# clyde river - nearest hotel: No hotel found
# boa vista - nearest hotel: Aipana Plaza Hotel
# zabid - nearest hotel: No hotel found
# dongsheng - nearest hotel: Meimei hotel
# esperance - nearest hotel: Hospitality
# maceio - nearest hotel: Maceió Hostel e Pousada
# jiaozuo - nearest hotel: Days Hotel & Suites Jiaozuo
# colesberg - nearest hotel: No hotel found
# lahad datu - nearest hotel: Silam Dynasty Hotel
# podor - nearest hotel: La Cour du Fleuve
# khani - nearest hotel: Alismereti
# vrangel - nearest hotel: No hotel found
# bonthe - nearest hotel: No hotel found
# kloulklubed - nearest hotel: The Adventures Inn
# vostok - nearest hotel: No hotel found
# deputatskiy - nearest hotel: No hotel found
# pacific grove - nearest hotel: Pacific Grove Inn
# budogoshch - nearest hotel: Пилигрим
# hovd - nearest hotel: Khovd hotel
# itapecerica - nearest hotel: Grande Hotel Ita
# lorengau - nearest hotel: Seeadler Bay Hotel
# port hedland - nearest hotel: The Esplanade Hotel
# parana - nearest hotel: Grand Hotel Alvear
# adzhamka - nearest hotel: No hotel found
# aswan - nearest hotel: Yaseen hotel
# chara - nearest hotel: No hotel found
# tinsukia - nearest hotel: Hotel Aroma Residency
# coihaique - nearest hotel: No hotel found
# aktas - nearest hotel: Тулпар гостиница
# verkhnyaya inta - nearest hotel: No hotel found
# hami - nearest hotel: Хами
# stargard szczecinski - nearest hotel: Hotel PTTK
# sala consilina - nearest hotel: La Marchesina
# concordia - nearest hotel: D'Charruas
# hualmay - nearest hotel: Hotel Mi Choacan
# guarapari - nearest hotel: Osmar Hotel
# la peca - nearest hotel: No hotel found
# new glasgow - nearest hotel: Travelodge Suites
# coahuayana - nearest hotel: No hotel found
# nyurba - nearest hotel: Марина
# rio grande - nearest hotel: Hotel Vila Moura Executivo
# joao camara - nearest hotel: No hotel found
# kobelyaky - nearest hotel: No hotel found
# illela - nearest hotel: HOTEL KADO
# karakol - nearest hotel: Неофит
# itarema - nearest hotel: Pousada Oásis
# ketchikan - nearest hotel: Cape Fox Lodge
# langxiang - nearest hotel: No hotel found
# mersing - nearest hotel: Mersing Inn Hotel
# vestmannaeyjar - nearest hotel: Westman Islands Inn
# emerald - nearest hotel: Emerald Central Hotel
# opuwo - nearest hotel: Ohakane Lodge
# puerto penasco - nearest hotel: Hotel Paraíso Del Desierto
# amuntai - nearest hotel: Grand Balqis Hotel
# leningradskiy - nearest hotel: No hotel found
# la cruz - nearest hotel: Hotel Las Palmas
# kaka - nearest hotel: No hotel found
# tokur - nearest hotel: No hotel found
# whitehorse - nearest hotel: Town & Mountain Hotel
# sorland - nearest hotel: Fagmek Resorts
# nemuro - nearest hotel: イーストハーバーホテル
# wattegama - nearest hotel: No hotel found
# vila - nearest hotel: Hotel Miracastro
# chulman - nearest hotel: Чорон
# rehoboth - nearest hotel: Suidwes Hotel
# suleja - nearest hotel: No hotel found
# ostrovnoy - nearest hotel: No hotel found
# xiongzhou - nearest hotel: 仁和国际大酒店
# misratah - nearest hotel: الفندق السياحى
# san cristobal - nearest hotel: Terra Sur
# camana - nearest hotel: Caja Arequipa
# laurel - nearest hotel: Quality Inn & Suites
# lethem - nearest hotel: Hotel Amazonas
# acajutla - nearest hotel: Hotel Lara
# palmer - nearest hotel: No hotel found
# voyvozh - nearest hotel: No hotel found
# kulpahar - nearest hotel: No hotel found
# berlevag - nearest hotel: No hotel found
# abu zabad - nearest hotel: No hotel found
# alice springs - nearest hotel: Aurora Alice Springs
# jiangyou - nearest hotel: No hotel found
# shintomi - nearest hotel: HOTEL AZ
# williston - nearest hotel: The El Rancho
# verkhoyansk - nearest hotel: Полюс холода
# anadyr - nearest hotel: Гостевой дом
# kamenka - nearest hotel: No hotel found
# benxi - nearest hotel: 富佳大酒店
# seymchan - nearest hotel: No hotel found
# cateel - nearest hotel: Edar's Inn
# socastee - nearest hotel: Affordable Efficiency Suites
# la ronge - nearest hotel: La Ronge Hotel and Suites
# kaitangata - nearest hotel: Hotel South Otago
# aegviidu - nearest hotel: No hotel found
# aleksandro-nevskiy - nearest hotel: No hotel found
# chaman - nearest hotel: No hotel found
# taltal - nearest hotel: Hostería Taltal
# san patricio - nearest hotel: No hotel found
# lons-le-saunier - nearest hotel: Hôtel du Cerf
# careiro da varzea - nearest hotel: Pousada "Aldenora"
# ambulu - nearest hotel: Hotel Ambulu
# mvomero - nearest hotel: No hotel found
# hasaki - nearest hotel: 大新旅館
# quelimane - nearest hotel: Mabassa
# langsa - nearest hotel: Harmoni Hotel
# haines junction - nearest hotel: Parkside Inn
# ossora - nearest hotel: No hotel found
# kuusamo - nearest hotel: Holiday Club Kuusamon Tropiikki
# talara - nearest hotel: Hospedaje El Aypate
# lagoa - nearest hotel: Casa da Madrinha
# naze - nearest hotel: ビジネス旅館畠山
# muisne - nearest hotel: Hostal Té de Menta
# uray - nearest hotel: Турсунт
# kahului - nearest hotel: Maui Seaside Hotel
# poum - nearest hotel: No hotel found
# port lavaca - nearest hotel: La Quinta Inn & Suites
# senneterre - nearest hotel: No hotel found
# greensburg - nearest hotel: No hotel found
# ormara - nearest hotel: No hotel found
# chicama - nearest hotel: Hotel Wasi
# barra da estiva - nearest hotel: Hotel Santa Rita
# mackenzie - nearest hotel: Royal Oak Inn and Suites & RV Park
# yarada - nearest hotel: daspalla
# porto novo - nearest hotel: Hôtel 6500 CFA
# cayenne - nearest hotel: Central Hôtel
# salalah - nearest hotel: Muscat International Hotel
# capaci - nearest hotel: Saracen Sands
# port hardy - nearest hotel: Quarterdeck Inn
# ha giang - nearest hotel: D
# pangoa - nearest hotel: No hotel found
# merritt - nearest hotel: Coldwater Hotel
# muyezerskiy - nearest hotel: No hotel found
# hamilton - nearest hotel: North Vista Manor
# dingle - nearest hotel: Hotel Edmundo
# ust-koksa - nearest hotel: Уймонская долина
# vizinga - nearest hotel: Надежда
# ararat - nearest hotel: No hotel found
# vicuna - nearest hotel: No hotel found
# necochea - nearest hotel: Cabañas Río Quequén
# vanino - nearest hotel: Пять Звёзд
# bambous virieux - nearest hotel: Otentic Eco Tent Experience
# oistins - nearest hotel: The Abidah By Accra
# invermere - nearest hotel: Windermere Point
# acarau - nearest hotel: No hotel found
# nishihara - nearest hotel: ユインチホテル南城
# malanje - nearest hotel: Hotel PORTVGALIA
# klaksvik - nearest hotel: Hotel Klaksvik
# macon - nearest hotel: Decatur Inn
# namatanai - nearest hotel: Namatanai Hotel
# tabuk - nearest hotel: Davidson Hotel
# cap malheureux - nearest hotel: Cape Garden
# sistranda - nearest hotel: Hotell Frøya
# guozhen - nearest hotel: No hotel found
# smithfield - nearest hotel: Holiday Inn Express & Suites Smithfield
# faya - nearest hotel: No hotel found
# vanavara - nearest hotel: No hotel found
# codigoro - nearest hotel: Albergo Pizzeria Da Elo
# fairbanks - nearest hotel: Westmark Fairbanks Hotel
# mayo - nearest hotel: The Westin
# tyrma - nearest hotel: No hotel found
# harper - nearest hotel: No hotel found
# kulhudhuffushi - nearest hotel: No hotel found
# labuhan - nearest hotel: No hotel found
# birjand - nearest hotel: مهمانسرای جهانگردی بیرجند
# tocopilla - nearest hotel: hotel Isidora
# impfondo - nearest hotel: Tropicana
# acapulco - nearest hotel: Hotel del Valle
# torre-pacheco - nearest hotel: Hotel Caleia Mar menor
# taoudenni - nearest hotel: No hotel found
# imeni vorovskogo - nearest hotel: Якорь (общежитие гостиничного типа)
# sept-iles - nearest hotel: Château Arnaud
# nikolayevsk-na-amure - nearest hotel: Север
# taseyevo - nearest hotel: No hotel found
# jalu - nearest hotel: فندق جالو السياحي
# bangangte - nearest hotel: Hôtel Cristal Fouandingon
# saldanha - nearest hotel: Hoedjesbaai
# mulege - nearest hotel: Hacienda Hotel
# miri - nearest hotel: Kenyalang Suites Miri
# teguldet - nearest hotel: Кедр
# enid - nearest hotel: La Quinta Inn & Suites by Wyndham Enid
# lannion - nearest hotel: Hôtel Arcadia
# narok - nearest hotel: Lexingtone Hotel
# aksu - nearest hotel: Akesu Tianyuan International Hotel
# baykalsk - nearest hotel: Куршавель
# launceston - nearest hotel: Hotel Charles
# port blair - nearest hotel: Andaman Ocean Breeze
# fort-shevchenko - nearest hotel: Akku
# celestun - nearest hotel: Hotel Flamingo Playa
# hajnowka - nearest hotel: Bartnik
# lashio - nearest hotel: Golden Kaniri Hotel
# grimshaw - nearest hotel: Pomeroy Inn & Suites Grimshaw
# faanui - nearest hotel: Oa Oa Lodge
# alma - nearest hotel: L'Escale du Routard
# san lazaro - nearest hotel: Come N' Dine
# mount isa - nearest hotel: Ibis Styles
# gulbene - nearest hotel: Baltā Pils
# gewane - nearest hotel: No hotel found
# razdolinsk - nearest hotel: No hotel found
# ndola - nearest hotel: Starscape Hotel
# mandiana - nearest hotel: Hôtel Prince
# sokoni - nearest hotel: La Madrugada Beach Hotel
# samarai - nearest hotel: No hotel found
# nagapattinam - nearest hotel: VPN Residency
# voh - nearest hotel: Le Vook
# akyab - nearest hotel: Yuzana Aung Motel 1
# colares - nearest hotel: Hotel Arribas
# lodja - nearest hotel: No hotel found
# desaguadero - nearest hotel: Hostal Don Carlos
# longyearbyen - nearest hotel: The Vault
# dakar - nearest hotel: 翁记小吃
# kikwit - nearest hotel: Grand Hôtel de Kikwit
# caravelas - nearest hotel: Pousada dos Navegantes
# dukat - nearest hotel: No hotel found
# nagato - nearest hotel: きらく
# pelham - nearest hotel: Fairfield Inn & Suites
# olafsvik - nearest hotel: North Star Hotel Snæfellsnes
# kajaani - nearest hotel: Original Sokos Hotel Valjus
# anloga - nearest hotel: Hotel de White House
# falmouth - nearest hotel: Broadmead Hotel
# katherine - nearest hotel: No hotel found
# kalmunai - nearest hotel: Saji new food
# roebourne - nearest hotel: No hotel found
# richards bay - nearest hotel: Protea Hotel
# yumen - nearest hotel: No hotel found
# ixtapa - nearest hotel: Ma. Cristina
# sapouy - nearest hotel: No hotel found
# seidu - nearest hotel: No hotel found
# iberia - nearest hotel: Inn of Iberia
# chala - nearest hotel: No hotel found
# kapuskasing - nearest hotel: Travelodge
# green river - nearest hotel: Hampton Inn & Suites
# lujan - nearest hotel: Bella vita
# howell - nearest hotel: Holiday Inn Express Howell
# nola - nearest hotel: Pamaran
# nizwa - nearest hotel: Nizwa Heritage Inn
# mgarr - nearest hotel: Quantin boutique hotel
# pimentel - nearest hotel: Hospedaje Calle del Sol
# kandy - nearest hotel: Royal Bar
# huarmey - nearest hotel: Hostal Santa Rosa
# stokmarknes - nearest hotel: Hurtigrutens Hus
# tortoli - nearest hotel: La Corte
# olinda - nearest hotel: Fidji Motel
# monaghan - nearest hotel: Westenra Arms Hotel
# juneau - nearest hotel: Ramada by Wyndham Juneau
# den helder - nearest hotel: Forest Hotel
# duluth - nearest hotel: Radisson Hotel Duluth-Harborview
# borovskoy - nearest hotel: Маржан
# saint-georges - nearest hotel: Deyna's City Inn
# the valley - nearest hotel: CeBlue
# balgazyn - nearest hotel: No hotel found
# gizo - nearest hotel: Gizo Hotel
# wonthaggi - nearest hotel: Wonthaggi Workmens Club
# santiago de cao - nearest hotel: Hostal El Encanto
# vila velha - nearest hotel: Hotel Prainha
# yamada - nearest hotel: No hotel found
# ayagoz - nearest hotel: Нур
# manaure - nearest hotel: hotel palaima
# zaysan - nearest hotel: Рахат қонақүй
# nautanwa - nearest hotel: Indo-Nepal
# petatlan - nearest hotel: No hotel found
# tezu - nearest hotel: No hotel found
# aleppo - nearest hotel: No hotel found
# polunochnoye - nearest hotel: No hotel found
# iskateley - nearest hotel: Авантаж
# colwyn bay - nearest hotel: Travelodge
# irbil - nearest hotel: Zakon Hotel
# cabedelo - nearest hotel: No hotel found
# kavaratti - nearest hotel: No hotel found
# turukhansk - nearest hotel: Гостиница ОАО "Туруханскэнерго"
# sompeta - nearest hotel: Haritha Beach Resort
# bilibino - nearest hotel: No hotel found
# moshenskoye - nearest hotel: No hotel found
# mitsamiouli - nearest hotel: Hotel le Paradis
# alice - nearest hotel: No hotel found
# chunskiy - nearest hotel: Теремок
# tutoia - nearest hotel: Pousada San Vicente
# carauari - nearest hotel: No hotel found
# tiznit - nearest hotel: No hotel found
# kieta - nearest hotel: No hotel found
# labuan - nearest hotel: Labuan Avenue Hotel
# moyamba - nearest hotel: Samies
# yerbogachen - nearest hotel: No hotel found
# romny - nearest hotel: флориана
# waitati - nearest hotel: No hotel found
# roma - nearest hotel: Wingate by Wyndham Rome
# tigil - nearest hotel: No hotel found
# casma - nearest hotel: No hotel found
# umm kaddadah - nearest hotel: No hotel found
# panji - nearest hotel: Kharisma
# port-gentil - nearest hotel: Tara-Mé
# huddersfield - nearest hotel: The Huddersfield Hotel
# lata - nearest hotel: Residencial Botânico
# nauta - nearest hotel: No hotel found
# tayginka - nearest hotel: Санаторий Дальняя дача
# rapid valley - nearest hotel: Sleep Inn & Suites
# ariquemes - nearest hotel: Aquarius
#                   City Country      Lat       Lng  Humidity  \
# 0               atuona      PF  -9.8000 -139.0333        76
# 1              paciran      ID  -6.8767  112.3761        83
# 2           mahibadhoo      MV   3.7833   72.9667        76
# 3    sao joao da barra      BR -21.6403  -41.0511        86
# 4              talnakh      RU  69.4865   88.3972       100
# ..                 ...     ...      ...       ...       ...
# 578               lata      PT  40.1629   -8.3327        94
# 579              nauta      PE  -4.5061  -73.5757        69
# 580           tayginka      RU  55.6244   60.5076        77
# 581       rapid valley      US  44.0625 -103.1463        57
# 582          ariquemes      BR  -9.9133  -63.0408        96
#
#                  Hotel Name
# 0              Pearl Resort
# 1            No hotel found
# 2            Coral View Inn
# 3      Pousada Mediterrâneo
# 4                    Талнах
# ..                      ...
# 578    Residencial Botânico
# 579          No hotel found
# 580  Санаторий Дальняя дача
# 581      Sleep Inn & Suites
# 582                Aquarius
#
# [583 rows x 6 columns]

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# Configure the map plot
map_plot_hotel = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    # by="Country",
    # hover_cols=["Hotel Name"],
    geo=True,
    tiles="EsriImagery",
    frame_width=800,
    frame_height=600,
    size="Humidity",
    scaling_factor=0.5,  # changed `scale` to `scaling_factor`
    color="City",
    title="City Humidity Heatmap"  # added closing parenthesis
)


# Display the map plot
map_plot_hotel
# Out:
# WARNING:param.main: scaling_factor option not found for points plot with bokeh; similar options include: []
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)
